# %%
install.packages("tidyverse")
install.packages("palmerpenguins")
install.packages("ggthemes")
install.packages("ggplot2")
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
library(tidyverse)
library(palmerpenguins)
library(ggplot2)
library(ggthemes)
# Out:
# ── Attaching core tidyverse packages ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
head(penguins)
# Out:
#   species island    bill_length_mm bill_depth_mm flipper_length_mm body_mass_g
# 1 Adelie  Torgersen 39.1           18.7          181               3750
# 2 Adelie  Torgersen 39.5           17.4          186               3800
# 3 Adelie  Torgersen 40.3           18.0          195               3250
# 4 Adelie  Torgersen   NA             NA           NA                 NA
# 5 Adelie  Torgersen 36.7           19.3          193               3450
# 6 Adelie  Torgersen 39.3           20.6          190               3650
#   sex    year
# 1 male   2007
# 2 female 2007
# 3 female 2007
# 4 NA     2007
# 5 female 2007
# 6 male   2007

# %%
ggplot(data = penguins, 
       mapping= aes(x=flipper_length_mm, y = body_mass_g, color=species)) + 
     geom_point() +
     geom_smooth(method="lm")
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 2 rows containing non-finite values (`stat_smooth()`).”
# Warning message:
# “Computation failed in `stat_smooth()`
# Caused by error in `dyn.load()`:
# ! unable to load shared object '/Users/tana2011/anaconda3/envs/r_env/lib/R/library/mgcv/libs/mgcv.dylib':
#   dlopen(/Users/tana2011/anaconda3/envs/r_env/lib/R/library/mgcv/libs/mgcv.dylib, 0x0006): Library not loaded: '@rpath/R/lib/libRlapack.dylib'
#   Referenced from: '/Users/tana2011/anaconda3/envs/r_env/lib/R/library/mgcv/libs/mgcv.dylib'
#   Reason: tried: '/Users/tana2011/anaconda3/envs/r_env/lib/R/library/mgcv/libs/../../../lib/R/lib/libRlapack.dylib' (no such file), '/Users/tana2011/anaconda3/envs/r_env/lib/R/library/mgcv/libs/../../../../R/lib/libRlapack.dylib' (no such file), '/Users/tana2011/anaconda3/envs/r_env/lib/R/library/mgcv/libs/../../../lib/R/lib/libRlapack.dylib' (no such file), '/Users/tana2011/anaconda3/envs/r_env/lib/R/library/mgcv/libs/../../../../R/lib/libRlapack.dylib' (no such file), '/Users/tana2011/anaconda3/envs/r_env/lib/R/lib/R/lib/libRlapack.dylib' (no such file), '/Users/tana2011/anaconda3/envs/r_env/lib/R/lib/../../R/lib/libRlapack.dylib' (no such file), '/”
# Warning message:
# “Removed 2 rows containing missing values (`geom_point()`).”
# plot without title
